# %% [markdown]
# # 計算ノードの削除
#
# ---
#
# 既存のOpenHPC環境のFeature（計算ノードグループ）からVCノードを削除します。実行中ジョブへの影響を確認したうえで、安全にノード数を縮小します。

# %% [markdown]
# ## 概要
#
# このNotebookでは、既存のOpenHPC環境に対して以下の操作を行います：
#
# 1. 削除するノードの指定（Feature選択、ノード数指定）
# 2. 削除前の安全措置（DRAIN・ジョブ確認・Slurmノード登録解除）
# 3. VCノードの削除
# 4. Ansibleの更新（known_hosts・インベントリ）
# 5. mdx VMの削除（mdx環境の場合のみ）
# 6. group_varsの更新

# %% [markdown]
# ## 準備
#
# 既存のOpenHPC環境にアクセスするための準備を行います。

# %% [markdown]
# ### VCCアクセストークンの入力
#
# VCノードを操作するためのアクセストークンを入力してください。

# %%
from getpass import getpass
vcc_access_token = getpass()

# %% [markdown]
# 入力されたアクセストークンが正しいことを、実際にVCCにアクセスして確認します。

# %%
from common import logsetting
from vcpsdk.vcpsdk import VcpSDK
vcp = VcpSDK(vcc_access_token)

# %% [markdown]
# ### UnitGroup名の指定
#
# 構築環境の UnitGroup名を指定します。
#
# > 「010-パラメータ設定.ipynb」と同じUnitGroup名(`ugroup_name`)を指定することで、既に入力したパラメータを引き継ぐことができます。

# %% [markdown]
# VCノードを作成時に指定した値を確認するために `group_vars` ファイル名の一覧を表示します。

# %%
# !ls -1 group_vars/*.yml | sed -e 's/^group_vars\///' -e 's/\.yml//' | sort

# %% [markdown]
# UnitGroup名を次のセルに指定してください。

# %%
# (例)
# ugroup_name = 'OpenHPC'

ugroup_name =

# %% [markdown]
# #### チェック
#
# 指定されたUnitGroup名が適切であることを確認します。

# %% [markdown]
# group_vars にfeature, partition 設定が記録されていることを確認します。

# %%
# %run scripts/group.py
gvars = load_group_vars(ugroup_name)

# group_vars にslurm_features, slurm_partitions が定義されていることを確認する
if not {"slurm_features", "slurm_partitions"} <= set(gvars.keys()):
    raise RuntimeError("Feature, Partition設定が未実施です")

# %% [markdown]
# Ansibleで接続できることを確認します。

# %%
# !ansible {ugroup_name}_master -m ping

# %% [markdown]
# ## 削除するノードの指定
#
# ノードを削除するFeature（計算ノードグループ）の選択と、削除するノード数の指定を行います。

# %% [markdown]
# ### 対象Featureの指定
#
# 現在の環境に登録されているFeatureと、それぞれのノード数を確認します。

# %%
# %run scripts/group.py
gvars = load_group_vars(ugroup_name)

for fname, fconfig in gvars["slurm_features"].items():
    current = fconfig["nodes"]
    max_nodes = len(fconfig["ip_addresses"])
    print(f"""- {fname}
    現在のノード数: {current} / 最大: {max_nodes}
    {'⚠ ノードが0です' if current == 0 else ''}""")

# %% [markdown]
# 上に表示されたFeature一覧から、ノードを削除するFeature名を次のセルで指定してください。

# %%
# ノードを削除する Feature 名を指定
# (例)
# target_feature = 'cpu-64core-aws'
# target_feature = 'gpu-a100-azure'

target_feature =

# %% [markdown]
# 指定されたFeatureの現在の状態を確認します。

# %%
feature_config = gvars["slurm_features"][target_feature]
vc_unit_name = feature_config.get("vc_unit", target_feature)

current_nodes = feature_config["nodes"]
max_nodes = len(feature_config["ip_addresses"])

print(f"""Feature: {target_feature}
VCユニット: {vc_unit_name}
現在のノード数: {current_nodes} / 最大: {max_nodes}""")

# %% [markdown]
# 選択したFeatureにスケジュール設定が行われていないことを確認します。

# %%
_schedule_target = gvars.get("vcnode_schedule_target_feature")
if _schedule_target is not None and _schedule_target == target_feature:
    raise RuntimeError(
        f"Feature '{target_feature}' にはスケジュール設定が行われています。"
        "スケジュール対象のFeatureからのノード削除はできません。"
        "先に821でスケジュール設定を削除してください。"
    )

# %% [markdown]
# ### 削除するノード数の指定
#
# 削除するノード数を`nodes_to_remove`に設定します。現在のノード数以下の値を指定してください。
#
# > ノードはIPアドレスの末尾側（後から追加されたノード）から削除されます。

# %%
# (例)
# nodes_to_remove = 1

nodes_to_remove =

# %% [markdown]
# #### チェック
#
# 削除する計算ノード数が適切かどうかチェックします。

# %%
if not isinstance(nodes_to_remove, int):
    msg = f'整数を指定してください: {nodes_to_remove}'
    raise RuntimeError(msg)
if nodes_to_remove < 1:
    msg = f'1以上の値を指定してください: {nodes_to_remove}'
    raise RuntimeError(msg)
if nodes_to_remove > current_nodes:
    msg = f'現在のノード数以下の値を指定してください: 削除 {nodes_to_remove} > 現在 {current_nodes}'
    raise RuntimeError(msg)

# %% [markdown]
# ## 削除前の安全措置
#
# VCノードを削除する前に、対象ノードで実行中のジョブがないかを確認し、安全に削除できる状態にします。

# %% [markdown]
# ### ノードをDRAINに変更
#
# 削除対象ノードへの新規ジョブ投入を停止します。Slurmに登録されているノードをDRAIN状態に設定します。

# %%
# %run scripts/group.py
feature_config = gvars["slurm_features"][target_feature]
new_nodes = current_nodes - nodes_to_remove
addrs_to_remove = feature_config["ip_addresses"][new_nodes:current_nodes]
node_list = build_slurm_hostlist(
    feature_config["hostname_template"],
    nodes_to_remove,
    first_index=new_nodes + 1,
)
# !ansible {ugroup_name}_master -b -m shell \
    -a "scontrol update NodeName={node_list} State=DRAIN \
    Reason='Node removal' 2>&1 || true"

# %% [markdown]
# Slurmの状態を確認します。

# %%
partitions = find_affected_partitions(gvars, target_feature)
if partitions:
    partitions_str = ','.join(partitions)
    # !ansible {ugroup_name}_master \
        -a "sinfo -p {partitions_str}"

# %% [markdown]
# ### 残存ジョブの確認（オプション）
#
# 削除対象ノードに投入されているジョブ数を確認する場合は、以下のセルを実行してください。表示された数が 0 であれば安全に削除できます。0 より大きい場合はこのセルを繰り返し実行し、ジョブが完了したことを確認してから次の手順に進んでください。

# %%
assert "partitions_str" in vars()
# !ansible {ugroup_name}_master -m shell \
    -a "squeue -h -p {partitions_str} | wc -l"

# %% [markdown]
# ### Slurmのノード登録を解除
#
# 実際にVCノードを削除する前にSlurmのノード登録を解除しておきます。

# %%
# !ansible {ugroup_name}_master -b -m shell \
    -a "scontrol delete NodeName={node_list} 2>&1 || true"

# %% [markdown]
# Slurmの状態を確認します。

# %%
assert "partitions_str" in vars()
# !ansible {ugroup_name}_master \
    -a "sinfo -p {partitions_str}"

# %% [markdown]
# ## VCノード削除
#
# 削除対象のVCノードを削除し、Ansible環境を更新します。

# %% [markdown]
# ### VCノードの削除
#
# 削除前に、現在のVCユニットの状態を確認します。

# %%
ug = vcp.get_ugroup(ugroup_name)
unit_compute = ug.get_unit(vc_unit_name)
unit_compute.df_nodes()

# %% [markdown]
# 対象のVCノードを削除します。

# %%
import contextlib
from time import sleep

for addr in addrs_to_remove:
    with contextlib.suppress(Exception):
        unit_compute.delete_nodes(ip_address=addr)
        sleep(5)

# %% [markdown]
# 削除後のVCユニットの状態を確認します。

# %%
unit_compute.df_nodes()

# %% [markdown]
# ### Ansibleの更新
#
# 削除したノードの情報をAnsible環境から除去します。

# %% [markdown]
# #### known_hostsの更新
#
# `~/.ssh/known_hosts` から削除したノードのエントリを削除します。

# %%
for addr in addrs_to_remove:
    # !ssh-keygen -R {addr} 2> /dev/null

# %% [markdown]
# #### inventory.yml の更新
#
# ansibleのインベントリファイルから削除したノードの情報を除去します。

# %%
# %run scripts/group.py

# 既存のinventoryを読み込む
try:
    with open('inventory.yml', 'r') as f:
        import yaml
        inventory = yaml.safe_load(f)
except FileNotFoundError:
    inventory = {}

# 計算ノードのグループ名
compute_group = f"{ugroup_name}_{vc_unit_name}"

# ノード情報を更新（残存ノードのみ）
remove_group_from_inventory_yml(compute_group, recursive=True)
inventory["all"]["children"][ugroup_name]["children"][compute_group] = {
    "hosts": {addr: {} for addr in unit_compute.find_ip_addresses()},
}
update_inventory_yml(inventory)

# inventoryのノード構成を確認
# !ansible-inventory --graph {ugroup_name}

# %% [markdown]
# ## mdx VMの削除
#
# 削除した計算ノードに対応するmdx VMを削除します。mdx以外のクラウドを利用している場合はこの章をスキップしてください。

# %% [markdown]
# ### mdx操作の準備

# %%
from getpass import getpass
mdx_token = getpass("mdx API token")

# %% [markdown]
# IPv4接続を強制するように設定します。

# %%
# %run scripts/mdx_ops.py
use_ipv4_only()

# %% [markdown]
# mdxプラグインを読み込みます。

# %%
from vcpsdk.plugins.mdx_ext import MdxResourceExt
mdx = MdxResourceExt(mdx_token)
mdx.set_current_project_by_name(gvars['mdx_project_name'])

# %% [markdown]
# ### VM削除対象の特定

# %%
# 削除するノードのホスト名を算出
hostname_template = feature_config["hostname_template"]
new_nodes = current_nodes - nodes_to_remove
hosts_to_remove = [
    hostname_template.format(new_nodes + i + 1)
    for i in range(nodes_to_remove)
]
print(f"削除対象VM: {hosts_to_remove}")

# %% [markdown]
# ### VMの強制停止と削除

# %%
from vcpsdk.plugins.mdx_ext import SLEEP_COUNT
from vcpsdk.plugins.mdx_ext import SLEEP_TIME_SEC
from time import sleep

# VM強制停止
for vm in hosts_to_remove:
    try:
        mdx.power_off_vm(vm, wait_for=False)
    except Exception as e:
        print(f"⚠ {vm} の停止でエラー: {e}")

for vm in hosts_to_remove:
    for i in range(SLEEP_COUNT):
        info = mdx.get_vm_info(vm)
        if info is None or info['status'] == 'PowerOFF':
            break
        sleep(SLEEP_TIME_SEC)
    else:
        raise RuntimeError(f'Error: VM {vm} not powered off.')

# %%
# VM削除
for vm in hosts_to_remove:
    try:
        mdx.destroy_vm(vm, wait_for=False)
    except Exception as e:
        print(f"⚠ {vm} の削除でエラー: {e}")

for vm in hosts_to_remove:
    for i in range(SLEEP_COUNT):
        info = mdx.get_vm_info(vm)
        if info is None:
            print(f"✓ {vm} を削除しました")
            break
        sleep(SLEEP_TIME_SEC)
    else:
        raise RuntimeError(f'Error: VM {vm} not destroyed.')

# %% [markdown]
# ## group_varsの更新

# %% [markdown]
# group_varsファイルの計算ノード数を更新します。

# %%
# %run scripts/group.py
feature_config['nodes'] -= nodes_to_remove
update_slurm_features(ugroup_name, target_feature, feature_config)

# %% [markdown]
# group_varsの内容を確認します。

# %%
# !cat group_vars/{ugroup_name}.yml
