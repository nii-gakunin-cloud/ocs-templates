# %% [markdown]
# # 計算ノードの追加
#
# ---
#
# 既存のOpenHPC環境のFeature（計算ノードグループ）にVCノードを追加します。Feature定義時に確保したIPアドレスの範囲内で、計算ノード数を増やすことができます。

# %% [markdown]
# ## 概要
#
# このNotebookでは、既存のOpenHPC環境に対して以下の操作を行います：
#
# 1. 追加するノードの指定（Feature選択、ノード数指定）
# 2. mdx VMの起動（mdx環境の場合のみ）
# 3. VCノードの起動
# 4. Ansibleのセットアップ（インベントリ・known_hosts・疎通確認）
# 5. Slurmノード登録確認
# 6. group_varsの更新
#
# ### 前提条件
#
# - 初期構築（010, 020）が完了し、正常にジョブ実行ができる状態であること
# - VCCアクセストークンが有効であること
# - Featureを作成した時に定義したIPアドレス数を超えて計算ノードを追加することはできません
# - 「811-ノード数のスケジュール設定.ipynb」でスケジュール設定を行なっている場合は、このNotebookで計算ノードを追加することはできません

# %% [markdown]
# ## 準備
#
# 既存のOpenHPC環境にアクセスするための準備を行います。

# %% [markdown]
# ### VCCアクセストークンの入力
#
# VCノードを操作するためのアクセストークンを入力してください。

# %%
from getpass import getpass
vcc_access_token = getpass()

# %% [markdown]
# 入力されたアクセストークンが正しいことを、実際にVCCにアクセスして確認します。

# %%
from common import logsetting
from vcpsdk.vcpsdk import VcpSDK
vcp = VcpSDK(vcc_access_token)

# %% [markdown]
# ### UnitGroup名の指定
#
# 構築環境の UnitGroup名を指定します。
#
# > 「010-パラメータ設定.ipynb」と同じUnitGroup名(`ugroup_name`)を指定することで、既に入力したパラメータを引き継ぐことができます。

# %% [markdown]
# VCノードを作成時に指定した値を確認するために `group_vars` ファイル名の一覧を表示します。

# %%
# !ls -1 group_vars/*.yml | sed -e 's/^group_vars\///' -e 's/\.yml//' | sort

# %% [markdown]
# UnitGroup名を次のセルに指定してください。

# %%
# (例)
# ugroup_name = 'OpenHPC'

ugroup_name =

# %% [markdown]
# #### チェック
#
# 指定されたUnitGroup名が適切であることを確認します。

# %% [markdown]
# group_vars にfeature, partition 設定が記録されていることを確認します。

# %%
# %run scripts/group.py
gvars = load_group_vars(ugroup_name)

# group_vars にslurm_features, slurm_partitions が定義されていることを確認する
if not {"slurm_features", "slurm_partitions"} <= set(gvars.keys()):
    raise RuntimeError("Feature, Partition設定が未実施です")

# %% [markdown]
# Ansibleで接続できることを確認します。

# %%
# !ansible {ugroup_name}_master -m ping

# %% [markdown]
# ## 追加するノードの指定
#
# ノードを追加するFeature（計算ノードグループ）の選択と、追加するノード数の指定を行います。

# %% [markdown]
# ### 対象Featureの指定
#
# 現在の環境に登録されているFeatureと、それぞれのノード数を確認します。

# %%
# %run scripts/group.py
gvars = load_group_vars(ugroup_name)

for fname, fconfig in gvars["slurm_features"].items():
    current = fconfig["nodes"]
    max_nodes = len(fconfig["ip_addresses"])
    print(f"""- {fname}
    現在のノード数: {current} / 最大: {max_nodes}
    {'⚠ IP アドレスが上限に達しています' if current >= max_nodes else ''}""")

# %% [markdown]
# 上に表示されたFeature一覧から、ノードを追加するFeature名を次のセルで指定してください。

# %%
# ノードを追加する Feature 名を指定
# (例)
# target_feature = 'cpu-64core-aws'
# target_feature = 'gpu-a100-azure'

target_feature =

# %% [markdown]
# 指定されたFeatureの現在の状態を確認します。

# %%
feature_config = gvars["slurm_features"][target_feature]
vc_unit_name = feature_config.get("vc_unit", target_feature)

current_nodes = feature_config["nodes"]
max_nodes = len(feature_config["ip_addresses"])

print(f"""Feature: {target_feature}
VCユニット: {vc_unit_name}
現在のノード数: {current_nodes} / 最大: {max_nodes}
追加可能なノード数: {max_nodes - current_nodes}""")

# %% [markdown]
# 選択したFeatureにスケジュール設定が行われていないことを確認します。

# %%
_schedule_target = gvars.get("vcnode_schedule_target_feature")
if _schedule_target is not None and _schedule_target == target_feature:
    raise RuntimeError(
        f"Feature '{target_feature}' にはスケジュール設定が行われています。"
        "スケジュール対象のFeatureに対するノード追加はできません。"
        "先に821でスケジュール設定を削除してください。"
    )

# %% [markdown]
# ### 追加するノード数の指定
#
# 追加するノード数を`nodes_to_add`に設定します。指定された値と現在のノード数を足した値が最大ノード数（IPアドレス数）以下となる値を指定してください。

# %%
# (例)
# nodes_to_add = 1

nodes_to_add =

# %% [markdown]
# #### チェック
#
# 追加する計算ノード数が適切かどうかチェックします。

# %%
if not isinstance(nodes_to_add, int):
    msg = f'整数を指定してください: {nodes_to_add}'
    raise RuntimeError(msg)
if nodes_to_add < 1:
    msg = f'1以上の値を指定してください: {nodes_to_add}'
    raise RuntimeError(msg)
if current_nodes + nodes_to_add > max_nodes:
    msg = f'最大ノード数を超えています: 現在 {current_nodes} + 追加 {nodes_to_add} > 最大 {max_nodes}'
    raise RuntimeError(msg)

# %% [markdown]
# ## mdx VMの起動
#
# 追加する計算ノードとなるmdx VMを起動し、VCノードとして使用できる状態にします。mdx以外のクラウドを利用している場合は、この章をスキップして次章の「VCノード起動」から実行してください。

# %% [markdown]
# ### mdx操作の準備

# %%
from getpass import getpass
mdx_token = getpass("mdx API token")

# %% [markdown]
# IPv4接続を強制するように設定します。

# %%
# %run scripts/mdx_ops.py
use_ipv4_only()

# %% [markdown]
# mdxプラグインを読み込みます。

# %%
from vcpsdk.plugins.mdx_ext import MdxResourceExt
mdx = MdxResourceExt(mdx_token)
mdx.set_current_project_by_name(gvars['mdx_project_name'])

# %% [markdown]
# ### 計算ノード用VMパラメータの設定
#
# Feature設定からVMスペックを生成します。

# %%
# %run scripts/mdx_ops.py
import os

with open(os.path.expanduser(gvars['ssh_public_key_path'])) as f:
    shared_key = f.read()

# Feature設定からVMスペックを生成
c_spec = mdx_get_compute_vm_spec_from_feature(
    mdx, feature_config, gvars['mdx_segment_id'], shared_key
)

# %%
# service_level の設定
from vcpsdk.plugins.mdx_ext import MDX_VM_SPEC_SCHEMA

if not 'service_level' in MDX_VM_SPEC_SCHEMA['properties']:
    MDX_VM_SPEC_SCHEMA['properties'].update(
        {'service_level': {'type': 'string'}}
    )

c_spec.update({'service_level': 'guarantee'})

# %% [markdown]
# ### VMデプロイ
#
# 追加するノードのVMをデプロイします。

# %%
# 追加するノードのホスト名リストを算出
hostname_template = feature_config["hostname_template"]
add_hostnames = [
    hostname_template.format(current_nodes + i + 1)
    for i in range(nodes_to_add)
]

# 追加するノードのIPアドレス
add_ip_addresses = feature_config["ip_addresses"][current_nodes:current_nodes + nodes_to_add]

# %%
# VM初期パスワード
initial_passwd = 'openhpcv3_mdx_vm_initial_password'

# %%
# !pip install --no-deps jupyter-autotime
# %load_ext autotime

# %%
# %run scripts/mdx_ops.py

mdx_deploy_vms(mdx, add_hostnames, c_spec,
               project=gvars['mdx_project_name'], verbose=True)

# %% [markdown]
# ### IPアドレスの変更

# %%
# %run scripts/mdx_ops.py

# {新IPアドレス: ホスト名} の辞書
c_add_etc_hosts = dict(zip(add_ip_addresses, add_hostnames))

# 初期パスワード設定
mdx_set_init_passwd(mdx, add_hostnames,
                    gvars['ssh_private_key_path'],
                    initial_passwd)

# IPアドレス変更
mdx_change_ipaddrs(mdx, c_add_etc_hosts,
                   os.path.expanduser(gvars['ssh_private_key_path']),
                   verbose=True)

# %% [markdown]
# ### VCノード向け設定
#
# mdx VMをVCノードとして使用できるように設定します。

# %%
# %run scripts/mdx_ops.py

vcppubkey = vcp.get_publickey()
mdx_init_vcp(list(c_add_etc_hosts.keys()),
             os.path.expanduser(gvars['ssh_private_key_path']),
             vcppubkey)

# %% [markdown]
# ## VCノード起動
#
# 指定された数のVCノードをVCユニットに追加し、Ansibleのセットアップ、Slurmノード登録確認を行います。

# %% [markdown]
# ### 追加するVCノードの起動

# %% [markdown]
# 追加するVCノードのIPアドレスを確認します。

# %%
ip_addresses = feature_config["ip_addresses"][current_nodes : current_nodes + nodes_to_add]
print("追加する IP アドレス")
for ip in ip_addresses:
    print(f"- {ip}")

# %% [markdown]
# VCノードを追加します。

# %%
ug = vcp.get_ugroup(ugroup_name)
unit_compute = ug.get_unit(vc_unit_name)
unit_compute.add_nodes(ip_addresses=ip_addresses)

# %% [markdown]
# VCノードの状態を確認します。

# %%
unit_compute.df_nodes()

# %% [markdown]
# ### Ansibleのセットアップ
#
# 起動した計算ノードに対してAnsibleで操作を行うための設定を行います。

# %% [markdown]
# #### inventory.yml の更新
#
# ansibleのインベントリファイルに追加したノードの情報を追加します。

# %%
# %run scripts/group.py

# 既存のinventoryを読み込む
try:
    with open('inventory.yml', 'r') as f:
        import yaml
        inventory = yaml.safe_load(f)
except FileNotFoundError:
    inventory = {}

# 計算ノードのグループ名
compute_group = f"{ugroup_name}_{vc_unit_name}"

# 新しい計算ノードを追加
inventory["all"]["children"][ugroup_name]["children"][compute_group] = {
    "hosts": {addr: {} for addr in unit_compute.find_ip_addresses()},
}

# inventory を更新
update_inventory_yml(inventory)

# inventoryのノード構成を確認
# !ansible-inventory --graph {ugroup_name}

# %% [markdown]
# #### known_hostsの更新
#
# `~/.ssh/known_hosts` の更新を行います。

# %%
from time import sleep

for retry in range(10):
    try:
        for addr in unit_compute.find_ip_addresses():
            # !ssh-keygen -R {addr} 2> /dev/null
            # !ssh-keyscan -H {addr} >> ~/.ssh/known_hosts 2> /dev/null
        print("✓ known_hostsを更新しました")
        break
    except:
        if retry < 9:
            print(f"リトライ中... ({retry + 1}/10)")
            sleep(10)
        else:
            raise

# %% [markdown]
# #### 疎通確認
#
# 追加した計算ノードへの疎通確認を行います。

# %%
# !ansible {compute_group} -m ping

# %% [markdown]
# ### Slurmノード登録確認
#
# 計算ノードを実際に起動するまでは、まだSlurmに認識されない場合があります。計算ノード起動後に `scontrol reconfigure` を実行してSlurmの状態を更新します。

# %%
# !ansible {ugroup_name}_master -b \
    -a "scontrol reconfigure"

# %% [markdown]
# Slurmの状態を確認し、追加ノードが正しく追加されていることを確認します。

# %%
# !ansible {ugroup_name}_master \
    -a "sinfo -o '%P %N %F %f'"

# %% [markdown]
# ## group_varsの更新

# %% [markdown]
# group_varsファイルの計算ノード数を更新します。

# %%
# %run scripts/group.py
feature_config['nodes'] += nodes_to_add
update_slurm_features(ugroup_name, target_feature, feature_config)

# %% [markdown]
# group_varsの内容を確認します。

# %%
# !cat group_vars/{ugroup_name}.yml

# %% [markdown]
# ## 補足
#
# このNotebookでは扱いませんが、計算ノードに対してパッケージの追加や設定ファイルの更新などを実施している場合は、別途追加した計算ノードにも同じ設定が必要です。
